# %%
# Import Libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# Import csv data
def load_dataset(fileName):
    allData = pd.read_csv('./' + fileName)
    return allData

# %%
# Get image file names from folders
def get_img_files(img_path):
    img_files = []
    for file in os.listdir(img_path):
        if file.endswith('.jpg'):
            img_files.append(file.replace('.jpg','')) # Strip .jpg extension from filenames - return img ID
    return img_files

# %%
# Preprocess all image files
def preprocess_img(img, img_path, img_size):
    image = load_img(os.path.join(img_path, img + '.jpg'), grayscale=False, color_mode='rgb', target_size=img_size)
    img_array = img_to_array(image)

    # normalize img_array
    img_array = img_array.astype('float32')
    img_array = (img_array / 255.0 - 0.5) * 2.0 # normalize by 255, then center and scale up to be from -1 to 1

    return img_array

# %%
def define_img_model(num_outputs, input_shape):
    input_tensor = tf.keras.layers.Input(shape=input_shape)
    model = tf.keras.applications.mobilenet.MobileNet(
        input_tensor = input_tensor,
        alpha = 1.0,
        weights = None,
        include_top = False
    )
    output_reshape = tf.keras.layers.Reshape((4096,))(model.output)
    output_dense = tf.keras.layers.Dense(200, activation='relu')(output_reshape)
    output_layer = tf.keras.layers.Dense(num_outputs, activation='softmax')(output_dense)

    final_model = tf.keras.Model(inputs=model.input, outputs=output_layer)
    return final_model

# %%
# model evaluation
def evaluate_model(model, trainX, trainY, testX, testY, num_epochs):
    verbose = 1
    scores, histories = list(), list()

    history = model.fit(trainX, trainY, epochs=num_epochs, validation_data=(testX,testY), verbose = verbose)
    # evaluate model performance
    _, acc = model.evaluate(testX, testY, verbose=1)
    print ('> %.3f' % (acc * 100.0))

    scores.append(acc)
    histories.append(history)

    return scores, histories

# %%
# present results
def summarize_diagnostics(histories):
    for i in range(len(histories)):
        #plot loss 
        plt.subplot(2,1,1)
        plt.title('Cross Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue', label='train')
        plt.plot(histories[i].history['val_loss'], color='orange', label='test')
        plt.legend()
        # plot accuracy
        plt.subplot(2,1,2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue', label='train')
        plt.plot(histories[i].history['val_accuracy'], color='orange', label='test')
        plt.legend()
    plt.show()

# %%
# Load in csv data
txtData = load_dataset('./train.csv')
train_img_path = './train/'
test_img_path = './test/'

train_img_files = get_img_files(train_img_path)
test_img_files = get_img_files(test_img_path)

# train_img_files = train_img_files[:2000] # for testing

# Isolate out unique categories
allCategories = pd.DataFrame(txtData['categories']).drop_duplicates(ignore_index=True)

# %%
# Read in image files
train_images = []
ylabels = []
img_size = (80,80)

# loop and read all image files into array
for img in train_img_files:
    img_array = preprocess_img(img, train_img_path, img_size)
    
    if img_array is not None:
        train_images.append(img_array.astype('float32'))

        # pull ylabel category
        img_index = txtData[txtData['ImgId'] == img].index.values[0]
        txt_row = txtData.iloc[img_index,:]
        category = txt_row[3]
        # description = txt_row[2]
        # title = txt_row[1]
        # ylabels.append(list(allCategories['categories']).index(category))
        ylabels.append(category)
        # print(title + '-' + category)

train_images = np.asarray(train_images)
ylabels = pd.get_dummies(ylabels).values

# %%
# Split data into training and testing data
img_trainX, img_testX, img_trainY, img_testY = train_test_split(train_images, ylabels, test_size = 0.3, random_state=0)
# Out:
# (29400, 80, 80, 3)

# %%
# Define model
input_shape = img_size + (3,)
model = define_img_model(num_outputs=ylabels.shape[1], input_shape=input_shape)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 80, 80, 3)]       0
#
#  conv1 (Conv2D)              (None, 40, 40, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 40, 40, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 40, 40, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 40, 40, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 40, 40, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 40, 40, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 40, 40, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 40, 40, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 40, 40, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 41, 41, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 20, 20, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 20, 20, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 20, 20, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 20, 20, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 20, 20, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 20, 20, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 20, 20, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 20, 20, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 20, 20, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 20, 20, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 20, 20, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 20, 20, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 21, 21, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 10, 10, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 10, 10, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 10, 10, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 10, 10, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 10, 10, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 10, 10, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 10, 10, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 10, 10, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 10, 10, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 10, 10, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 10, 10, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 10, 10, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 11, 11, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 5, 5, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 5, 5, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 5, 5, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 5, 5, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 5, 5, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 5, 5, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 5, 5, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 5, 5, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 5, 5, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 5, 5, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 5, 5, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 5, 5, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 5, 5, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 5, 5, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 5, 5, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 5, 5, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 5, 5, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 5, 5, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 5, 5, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 5, 5, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 5, 5, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 5, 5, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 5, 5, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 5, 5, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 6, 6, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 2, 2, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 2, 2, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 2, 2, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 2, 2, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 2, 2, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 2, 2, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 2, 2, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 2, 2, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 2, 2, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 2, 2, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 2, 2, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 2, 2, 1024)        0
#
#  reshape_4 (Reshape)         (None, 4096)              0
#
#  dense_8 (Dense)             (None, 200)               819400
#
#  dense_9 (Dense)             (None, 21)                4221
#
# =================================================================
# Total params: 4,052,485
# Trainable params: 4,030,597
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# Train model
num_epochs = 10
scores, histories = evaluate_model(model, img_trainX, img_trainY, img_testX, img_testY, num_epochs)
# Out:
# Epoch 1/10
# 919/919 [==============================] - 750s 809ms/step - loss: 3.0404 - accuracy: 0.0555 - val_loss: 3.0001 - val_accuracy: 0.0607
# Epoch 2/10
# 919/919 [==============================] - 478s 520ms/step - loss: 2.9722 - accuracy: 0.0784 - val_loss: 3.0588 - val_accuracy: 0.0687
# Epoch 3/10
# 919/919 [==============================] - 475s 517ms/step - loss: 2.9369 - accuracy: 0.0842 - val_loss: 2.9577 - val_accuracy: 0.0773
# Epoch 4/10
# 919/919 [==============================] - 475s 516ms/step - loss: 2.9164 - accuracy: 0.0867 - val_loss: 2.9269 - val_accuracy: 0.0784
# Epoch 5/10
# 919/919 [==============================] - 604s 657ms/step - loss: 2.9028 - accuracy: 0.0894 - val_loss: 2.9427 - val_accuracy: 0.0792
# Epoch 6/10
# 349/919 [==========>...................] - ETA: 8:00 - loss: 2.8819 - accuracy: 0.1032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4204\3478783335.py in <module>
#       1 # Train model
#       2 num_epochs = 10
# ----> 3 scores, histories = evaluate_model(model, img_trainX, img_trainY, img_testX, img_testY, num_epochs)
#
# ~\AppData\Local\Temp\ipykernel_4204\2667073658.py in evaluate_model(model, trainX, trainY, testX, testY, num_epochs)
#       4     scores, histories = list(), list()
#       5
# ----> 6     history = model.fit(trainX, trainY, epochs=num_epochs, validation_data=(testX,testY), verbose = verbose)
#       7     # evaluate model performance
#       8     _, acc = model.evaluate(testX, testY, verbose=1)
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496     return graph_function._call_flat(
# -> 2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#    2499   @property
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1861       # No tape is watching; skip to running the function.
#    1862       return self._build_call_outputs(self._inference_function.call(
# -> 1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#    1865         args,
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# c:\Users\edric\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
# Diagnostics
summarize_diagnostics(histories)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4204\4015958022.py in <module>
#       1 # Diagnostics
# ----> 2 summarize_diagnostics(histories)
#
# NameError: name 'histories' is not defined
